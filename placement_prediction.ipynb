# %% [markdown]
# 1. Importing libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#   cgpa     iq placement
# 0  6,8  123.0       Yes
# 1  5,9  106.0        No
# 2  5,3  121.0        No
# 3  7,4  132.0       Yes
# 4  5,8  142.0        No

# %%
df.shape
# Out:
# (100, 3)

# %%
df.isnull()
# Out:
#      cgpa     iq  placement
# 0   False  False      False
# 1   False  False      False
# 2   False  False      False
# 3   False  False      False
# 4   False  False      False
# ..    ...    ...        ...
# 95  False  False      False
# 96  False  False      False
# 97  False  False      False
# 98  False  False      False
# 99  False  False      False
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa         5
# iq           0
# placement    0
# dtype: int64

# %%
df
# Out:
#    cgpa     iq placement
# 0   6,8  123.0       Yes
# 1   5,9  106.0        No
# 2   5,3  121.0        No
# 3   7,4  132.0       Yes
# 4   5,8  142.0        No
# ..  ...    ...       ...
# 95  4,3  200.0        No
# 96  4,4   42.0        No
# 97  6,7  182.0       Yes
# 98  6,3  103.0       Yes
# 99  6,2  113.0       Yes
#
# [100 rows x 3 columns]

# %%
pl=pd.read_csv('placement_1.csv')

# %%
pl.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
pl.shape
# Out:
# (100, 4)

# %%
pl=pl.iloc[:, 1:4]

# %%
pl
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
plt.scatter(pl['cgpa'], pl['iq'], c=pl['placement'])

# %%
X=pl.iloc[:, 0:2]

# %%
y=pl.iloc[:, -1]

# %%
X, y
# Out:
# (    cgpa     iq
#  0    6.8  123.0
#  1    5.9  106.0
#  2    5.3  121.0
#  3    7.4  132.0
#  4    5.8  142.0
#  ..   ...    ...
#  95   4.3  200.0
#  96   4.4   42.0
#  97   6.7  182.0
#  98   6.3  103.0
#  99   6.2  113.0
#
#  [100 rows x 2 columns],
#  0     1
#  1     0
#  2     0
#  3     1
#  4     0
#       ..
#  95    0
#  96    0
#  97    1
#  98    1
#  99    1
#  Name: placement, Length: 100, dtype: int64)

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
train_X, test_X, train_y, test_y=train_test_split(X, y, test_size=0.1)

# %%
train_X
# Out:
#     cgpa     iq
# 66   6.9   96.0
# 54   6.4  141.0
# 3    7.4  132.0
# 87   5.7  132.0
# 65   8.1  166.0
# ..   ...    ...
# 34   4.8  163.0
# 26   7.0  199.0
# 35   6.8   90.0
# 12   5.4  139.0
# 32   7.0  139.0
#
# [90 rows x 2 columns]

# %%
test_X.shape
# Out:
# (10, 2)

# %%
train_y.shape
# Out:
# (90,)

# %%
test_y.shape
# Out:
# (10,)

# %%
train_X
# Out:
#     cgpa     iq
# 66   6.9   96.0
# 54   6.4  141.0
# 3    7.4  132.0
# 87   5.7  132.0
# 65   8.1  166.0
# ..   ...    ...
# 34   4.8  163.0
# 26   7.0  199.0
# 35   6.8   90.0
# 12   5.4  139.0
# 32   7.0  139.0
#
# [90 rows x 2 columns]

# %%
scaler=StandardScaler()

# %%
scaler.fit_transform(train_X)
# Out:
# array([[ 0.75895091, -0.65078174],
#        [ 0.33043408,  0.48970552],
#        [ 1.18746773,  0.26160806],
#        [-0.26948947,  0.26160806],
#        [ 1.78739128,  1.12330955],
#        [-0.1837861 ,  0.51504968],
#        [ 0.24473072, -0.47337261],
#        [ 0.84465427, -0.24527516],
#        [ 1.10176436, -0.14389852],
#        [-1.38363321, -2.01936645],
#        [ 0.67324754,  0.03351061],
#        [ 0.84465427,  1.351407  ],
#        [-1.04081975,  1.19934203],
#        [ 0.75895091,  0.43901719],
#        [ 1.27317109,  0.92055626],
#        [ 1.78739128,  0.69245881],
#        [-0.86941302, -0.09321019],
#        [-1.72644667, -1.18300913],
#        [ 0.50184081,  0.41367303],
#        [ 1.10176436, -1.81661316],
#        [-0.01237937, -1.94333396],
#        [-0.69800629, -0.80284671],
#        [-0.78370966, -1.41110658],
#        [-0.86941302, -1.48713906],
#        [-0.95511639,  0.74314713],
#        [-1.12652311, -0.01717771],
#        [ 0.24473072,  0.16023142],
# ...

# %%
scaler.fit_transform(test_X)
# Out:
# array([[ 1.89174166, -1.43224638],
#        [-1.21967554,  0.0078551 ],
#        [-0.47293541, -0.14924688],
#        [ 0.52271809, -0.72528747],
#        [ 0.77163146, -0.64673648],
#        [-0.72184879,  2.18109915],
#        [-0.72184879, -0.22779787],
#        [ 1.14500153,  1.08138529],
#        [ 0.02489134,  0.66244668],
#        [-1.21967554, -0.75147113]])

# %%
regressor=LogisticRegression()

# %%
regressor.fit(train_X, train_y)
# Out:
# LogisticRegression()

# %%
y_predict=regressor.predict(test_X)
y_predict
# Out:
# array([1, 0, 0, 1, 1, 0, 0, 1, 0, 0])

# %%
regressor.coef_
# Out:
# array([[ 3.08214179, -0.00461495]])

# %%
test_y
# Out:
# 90    1
# 51    0
# 49    0
# 99    1
# 13    1
# 16    0
# 19    0
# 97    1
# 85    1
# 59    0
# Name: placement, dtype: int64

# %%
scoring=accuracy_score(test_y, y_predict)

# %%
scoring
# Out:
# 0.9

# %%
plot_decision_regions(train_X.values, train_y.values, clf=regressor)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
import pickle

# %%
pickle.dump()
