# %%
import numpy as np

# %%
scalar=np.array(7)

# %%
scalar.ndim
# Out:
# 0

# %%
vector=np.array([2,3])

# %%
vector.ndim
# Out:
# 1

# %%
matrix=np.array([[3,4,5,
                  7,5,4]])

# %%
matrix.ndim
# Out:
# 2

# %%
tensor=np.array([[[4,3,6,
                  4,5,6,
                  5,2,3]]])

# %%
tensor.ndim
# Out:
# 3

# %%
tensor
# Out:
# array([[[4, 3, 6, 4, 5, 6, 5, 2, 3]]])

# %%
matrices=np.array([[3,4,5], [3,2,5], [0,3,2], [9,1,5]])

# %%
matrices
# Out:
# array([[3, 4, 5],
#        [3, 2, 5],
#        [0, 3, 2],
#        [9, 1, 5]])

# %%
matrices.ndim
# Out:
# 2
