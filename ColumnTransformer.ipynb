# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('covid_toy.csv')

# %%
df.sample(5)
# Out:
#     age  gender  fever   cough       city has_covid
# 36   38  Female  101.0    Mild  Bangalore        No
# 61   81  Female   98.0  Strong     Mumbai        No
# 35   82  Female  102.0  Strong  Bangalore        No
# 47   18  Female  104.0    Mild  Bangalore        No
# 27   33  Female  102.0  Strong      Delhi        No

# %%
df['city'].values
# Out:
# array(['Kolkata', 'Delhi', 'Delhi', 'Kolkata', 'Mumbai', 'Bangalore',
#        'Bangalore', 'Mumbai', 'Bangalore', 'Delhi', 'Delhi', 'Mumbai',
#        'Kolkata', 'Bangalore', 'Bangalore', 'Kolkata', 'Kolkata', 'Delhi',
#        'Bangalore', 'Bangalore', 'Bangalore', 'Bangalore', 'Kolkata',
#        'Delhi', 'Kolkata', 'Mumbai', 'Kolkata', 'Delhi', 'Kolkata',
#        'Mumbai', 'Delhi', 'Kolkata', 'Delhi', 'Kolkata', 'Mumbai',
#        'Bangalore', 'Bangalore', 'Kolkata', 'Delhi', 'Kolkata', 'Delhi',
#        'Kolkata', 'Delhi', 'Bangalore', 'Delhi', 'Bangalore', 'Mumbai',
#        'Bangalore', 'Bangalore', 'Mumbai', 'Delhi', 'Kolkata',
#        'Bangalore', 'Delhi', 'Mumbai', 'Mumbai', 'Kolkata', 'Bangalore',
#        'Mumbai', 'Kolkata', 'Bangalore', 'Mumbai', 'Bangalore',
#        'Bangalore', 'Mumbai', 'Bangalore', 'Kolkata', 'Bangalore',
#        'Kolkata', 'Delhi', 'Delhi', 'Delhi', 'Kolkata', 'Kolkata',
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#     age  gender  fever   cough       city has_covid
# 51   11  Female  100.0  Strong    Kolkata       Yes
# 60   24  Female  102.0  Strong  Bangalore       Yes
# 9    64  Female  101.0    Mild      Delhi        No
# 6    14    Male  101.0  Strong  Bangalore        No
# 3    31  Female   98.0    Mild    Kolkata        No

# %%
X_train, X_test, y_train, y_test=train_test_split(df.iloc[:, 0:5], df.iloc[:, 5], test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 64   42    Male  104.0    Mild     Mumbai
# 22   71  Female   98.0  Strong    Kolkata
# 59    6  Female  104.0    Mild    Kolkata
# 99   10  Female   98.0  Strong    Kolkata
# 43   22  Female   99.0    Mild  Bangalore
# ..  ...     ...    ...     ...        ...
# 54   60  Female   99.0    Mild     Mumbai
# 12   25  Female   99.0  Strong    Kolkata
# 5    84  Female    NaN    Mild  Bangalore
# 35   82  Female  102.0  Strong  Bangalore
# 90   59  Female   99.0  Strong      Delhi
#
# [80 rows x 5 columns]

# %%
ohe=OneHotEncoder()

# %%
new_X_train=ohe.fit_transform(X_train[['gender', 'city']]).toarray()

# %%
new_X_test=ohe.fit_transform(X_test[['gender', 'city']]).toarray()

# %%
#new_X_train

# %%
data_ohe=np.hstack((new_X_train, X_train[['age', 'fever']].values))

# %%
df.isnull().sum().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
st=SimpleImputer(strategy='mean')

# %%
new_one=st.fit_transform(df[['fever']])

# %%
new_one.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-9324247d13c4> in <cell line: 0>()
# ----> 1 new_one.isnull()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isnull'

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 64   42    Male  104.0    Mild     Mumbai
# 22   71  Female   98.0  Strong    Kolkata
# 59    6  Female  104.0    Mild    Kolkata
# 99   10  Female   98.0  Strong    Kolkata
# 43   22  Female   99.0    Mild  Bangalore
# ..  ...     ...    ...     ...        ...
# 54   60  Female   99.0    Mild     Mumbai
# 12   25  Female   99.0  Strong    Kolkata
# 5    84  Female    NaN    Mild  Bangalore
# 35   82  Female  102.0  Strong  Bangalore
# 90   59  Female   99.0  Strong      Delhi
#
# [80 rows x 5 columns]

# %%
from sklearn.compose import ColumnTransformer

# %%
ct=ColumnTransformer(transformers=[
    ('st', SimpleImputer(strategy='mean'), ['fever']),
    ('ohe', OneHotEncoder(drop='first'), ['gender', 'city']),
    ('oe', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough'])
], remainder='passthrough')

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
ct.fit_transform(X_train)
# Out:
# array([[104.        ,   1.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  42.        ],
#        [ 98.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   1.        ,  71.        ],
#        [104.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,   6.        ],
#        [ 98.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   1.        ,  10.        ],
#        [ 99.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  22.        ],
#        [ 98.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,  31.        ],
#        [ 98.        ,   1.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  73.        ],
#        [ 98.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  80.        ],
# ...
