# %%
import numpy as np 

import matplotlib.pyplot as plt

from sklearn.datasets import make_regression

from sklearn.linear_model import LinearRegression

# %%
X, y= make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X, y)

# %%
regressor=LinearRegression()

# %%
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([39.99639845])

# %%
regressor.intercept_
# Out:
# -1.143454069605962

# %%
plt.scatter(X, y)
plt.plot(X, regressor.predict(X))

# %%
m = 39.99

# %%
class GradientDescentRegressor:

    def __init__(self, learning_rate, epochs):
        self.m=100
        self.c= -30
        self.lr= learning_rate
        self.epochs = epochs
    
    def fit(self, X, y):
        for i in range(self.epochs):
            loss_slope_c = 2 * np.sum(y - self.m*X.ravel() - self.c)
            loss_slope_m = 2 * np.sum((y - self.m*X.ravel() - self.c)*X.ravel())
            self.c = self.c - (self.lr * loss_slope_c)
            self.m = self.m - (self.lr * loss_slope_m)
            #print(self.b)
        print(self.c, self.m)
    
    def predict(self, X):
        return sefl.m * X + sefl.b

# %%
gdg= GradientDescentRegressor(0.001, 50)

# %%
gdg.fit(X, y)
# Out:
# 2881526.8981225486 6165359.530552448

# %%
regressor.intercept_
# Out:
# -1.143454069605962
