# %%
class myLR:
  def __init__(self):
    self.m=None
    self.c=None

  def fit(self,X_train, y_train):
    numerator=0
    denominator=0
    for i in range(X_train.shape[0]):
      numerator=numerator+((X_train.iloc[i,0]-X_train.iloc[:,0].mean())*(y_train.iloc[i]-y_train.mean()))
      denominator=denominator+((X_train.iloc[i,0]-X_train.iloc[:,0].mean())*(X_train.iloc[i,0]-X_train.iloc[:,0].mean()))
      self.m=numerator/denominator
      self.c=y_train.mean()-(self.m*X_train.iloc[:,0].mean())
      print(self.m)
      print(self.c)


  def predict(self, X_test):
    return self.m * X_test + self.c

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('placement_package.csv')

# %%
df.sample(5)
# Out:
#      cgpa  package
# 156  7.38     3.13
# 67   6.51     2.89
# 116  9.04     3.33
# 100  7.95     4.14
# 159  8.71     4.08

# %%
X=df.iloc[:, 0:1]
y=df.iloc[:, 1]

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape, X_test.shape
# Out:
# ((160, 1), (40, 1))

# %%
lr=myLR()

# %%
lr.fit(X_train, y_train)
# Out:
# 0.8400666389004626
# -2.8680758017493027
# 0.46924606814696196
# -0.2760631884680049
# 0.4735784832135009
# -0.3063464990071707
# 0.4368114508414633
# -0.04934724066615104
# 0.4903032804315722
# -0.42325178626166293
# 0.4839693968140894
# -0.3789783356431844
# 0.48640320794067066
# -0.3959905233047918
# 0.49703213346001257
# -0.47028604837714694
# 0.4719939239065887
# -0.2952705284868111
# 0.4397481783518019
# -0.06987478241794864
# 0.47590917171947894
# -0.3226378659959255
# 0.5163397239276872
# -0.6052448990217885
# 0.521190861769847
# -0.6391540493423702
# 0.529161602582466
# -0.6948690294512763
# 0.5305281218210268
# -0.7044209135213642
# 0.529922374981655
# -0.7001867809733322
# 0.5639383415253931
# -0.9379562611161529
# 0.5716752372889344
# -0.9920366789473216
# 0.5729455718328632
# -1.0009162380134748
# 0.5740242768181008
# -1.0084563184412234
# 0.5814518869758193
# -1.0603748492180411
# 0.5765851988353474
# -1.0263570032841516
# 0.5726511703244137
# -0.9988583898695067
# ...

# %%
lr.predict(X_test.iloc[2,0])
# Out:
# np.float64(2.3846456814965085)
